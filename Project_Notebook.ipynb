# %% [markdown]
# # MACHINE LEARNING 11: Multi-Objective Sustainability Auditor
# ## A US-Nepal Comparative Study on the Water-Energy Nexus
# **MSc Data Science and Computational Intelligence**\n
# ---
# ### Research Pipeline Control Center
# This notebook executes the modular research scripts to ensure 100% technical reproducibility of the thesis findings.
#
# | Step | Research Phase | Target Outcome |
# |:---|:---|:---|
# | **01** | Data Acquisition | US & Nepal raw telemetry retrieval |
# | **03** | Data Engineering | CW-Stress labelling & merging |
# | **04** | ML Tournament | SVM-RBF training (**91.4% Accuracy**) |
# | **05** | Research Contributions | SHAP explainability & Paradox detection |
# | **08** | Nepal Regional Study | Zero-shot transferability study |
# | **11** | Clustering Validation | Unsupervised label verification |
# | **12** | Statistical Significance | Paired T-Test (SVM vs. RF) |
# | **14** | Diagnostic Audit | Final visual artifact generation |

# %% [markdown]
# ## 1. Setup & Environment

# %%
import os
print("✅ Project Environment Ready")

# %% [markdown]
# ## 2. Data Acquisition (Steps 1 & 2)
# Downloads US Energy/Weather and Nepal weather telemetry.

# %%
# %run download_2023_EIA.py
# %run download_2023_Weather.py
# %run download_kathmandu.py

# %% [markdown]
# ## 3. Data Processing & Labelling (Step 3)
# Merges raw inputs and applies the multi-objective CW-Stress index.

# %%
# %run Step3_Merge_and_Engineer.py

# %% [markdown]
# ## 4. Machine Learning Tournament (Step 4)
# Trains the SVM-RBF winner and compares it against benchmarks.

# %%
# %run Step4_Machine_Learning.py

# %% [markdown]
# ## 5. Research Contributions & XAI (Step 5)
# Generates SHAP explainability plots and identifies Carbon-Water paradoxes.

# %%
# %run Step5_Research_Contributions.py

# %% [markdown]
# ## 6. Nepal Transferability Study (Step 8)
# Evaluates model performance across Nepal's clean-grid regional zones.

# %%
# %run Step8_Process_Nepal_Master.py

# %% [markdown]
# ## 7. Unsupervised Validation (Step 11)
# Validates the labelling logic using K-Means clustering and PCA.

# %%
# %run Step11_Clustering_Validation.py

# %% [markdown]
# ## 8. Statistical Significance (Step 12)
# Proves the mathematical superiority of the SVM model.

# %%
# %run Step12_Statistical_Significance.py

# %% [markdown]
# ## 9. Final Diagnostic Audit (Step 14)
# Final check of all diagnostic artifacts and error distributions.

# %%
# %run Step14_Error_and_Feature_Audit.py

# %% [markdown]
# ---
# **End of Research Pipeline.** All artifacts are saved in the `figures/` directory.
